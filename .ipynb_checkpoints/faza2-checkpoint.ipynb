# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from datetime import datetime
import category_encoders as ce
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import PowerTransformer
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_regression
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
from sklearn.impute import KNNImputer

# %%
products = pd.read_csv("data/product.csv", sep='\t')
sessions = pd.read_csv("data/session.csv", sep='\t')
users = pd.read_csv("data/user.csv", sep='\t')

# %% [markdown]
# Vyriešené chyby z predchádzajúcej fázy

# %%
users = users.drop_duplicates(subset='user_id', keep='first')
users['race'] = users['race'].fillna('unspecified')
users['birthdate'] = pd.to_datetime(users['birthdate'], errors='coerce')
sessions['ack']=sessions['ack'].astype(int)
duplikatne_riadky = sessions[sessions.duplicated()]
sessions.drop_duplicates(inplace=True)
sessions['session_start'] = pd.to_datetime(sessions['session_start'], errors='coerce')

# %%
products.head()
# Out:
#   code             location       store_name    product_ean
# 0   HR        Europe/Zagreb            Split  3618641987900
# 1   CN        Asia/Shanghai           Heyuan   890698872559
# 2   NL     Europe/Amsterdam        Barneveld  2447491624236
# 3   MX  America/Mexico_City           Tuxtla  2920947188549
# 4   US     America/New_York  Sun City Center  4869841703558

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14962 entries, 0 to 14961
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         14948 non-null  object
#  1   location     14962 non-null  object
#  2   store_name   14962 non-null  object
#  3   product_ean  14962 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 467.7+ KB

# %%
sessions.head()
# Out:
#    pct_wild_mouse screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175           600    2.02433      47.57172         77.67966
# 1        35.01962           768    2.73613      44.98978         40.38256
# 2        61.41151           800    2.30551      56.16179         29.32719
# 3        44.86510           600    4.67376      51.02882         57.35852
# 4        61.66559           800    6.29241      33.35663         50.05876
#
#    pct_click_product_info  wild_mouse_duration       session_start  \
# 0                50.06169             16.15405 2022-04-16 18:13:19
# 1                53.78582             16.44725 2022-09-07 09:34:07
# 2                61.74431             16.28032 2022-08-01 19:22:50
# 3                44.10727             16.97307 2020-03-28 06:00:21
# 4                36.03935             17.26692 2023-02-12 18:25:13
#
#    total_load_time  pct_click  ... session_id  pct_scroll_move_duration  ack  \
# 0          3.66109   15.21849  ...     341891                  17.64845    0
# 1          3.06183   17.79744  ...    1302699                  16.90542    1
# 2          4.30491   16.56530  ...    1346090                  20.42301    1
# 3          2.66177   14.10738  ...     320000                  19.13251    0
# 4          3.67287   19.04736  ...     291366                  13.65667    0
#
#    scroll_move_total_rel_distance  page_activity_duration  \
# 0                        13.31028                15.50704
# 1                        18.33657                15.76245
# 2                         7.24767                15.94806
# 3                         9.27093                17.21545
# 4                        19.71573                17.01892
#
#    mouse_move_total_rel_distance  browser_name  pct_rage_click  \
# 0                       16.78128        safari        73.88232
# 1                       16.67535       firefox        36.27018
# 2                       17.84916         opera        44.07316
# 3                       15.85436          edge        61.91555
# 4                       16.65385        chrome        21.36066
#
#    session_duration  pct_mouse_click
# 0          93.50794              NaN
# 1          83.05534         15.63971
# 2         212.16973         13.54653
# 3          62.13615         14.83673
# 4         157.60814         15.17088
#
# [5 rows x 25 columns]

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10962 entries, 0 to 11093
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  10951 non-null  float64
#  1   screen_height                   10962 non-null  object
#  2   pct_input                       10951 non-null  float64
#  3   pct_scrandom                    10951 non-null  float64
#  4   pct_scroll_move                 10951 non-null  float64
#  5   pct_click_product_info          10951 non-null  float64
#  6   wild_mouse_duration             10951 non-null  float64
#  7   session_start                   10962 non-null  datetime64[ns]
#  8   total_load_time                 10962 non-null  float64
#  9   pct_click                       10951 non-null  float64
#  10  screen_width                    10962 non-null  object
#  11  pct_doubleclick                 10951 non-null  float64
#  12  product_ean                     10962 non-null  int64
#  13  pct_mouse_move                  10951 non-null  float64
#  14  user_id                         10962 non-null  int64
#  15  session_id                      10962 non-null  int64
#  16  pct_scroll_move_duration        10951 non-null  float64
#  17  ack                             10962 non-null  int32
#  18  scroll_move_total_rel_distance  10951 non-null  float64
#  19  page_activity_duration          10951 non-null  float64
#  20  mouse_move_total_rel_distance   10951 non-null  float64
#  21  browser_name                    10962 non-null  object
#  22  pct_rage_click                  10951 non-null  float64
#  23  session_duration                10962 non-null  float64
#  24  pct_mouse_click                 10951 non-null  float64
# dtypes: datetime64[ns](1), float64(17), int32(1), int64(3), object(3)
# memory usage: 2.1+ MB

# %%
users.head()
# Out:
#             username residence  \
# 0  gabrieladas-neves       NaN
# 1      ferreirajulia       NaN
# 2          isadora80       NaN
# 3          adriana04       NaN
# 4          kellygreg       NaN
#
#                                  current_location                  name  \
# 0   (Decimal('-37.802134'), Decimal('79.453092'))        Sabrina da Luz
# 1    (Decimal('4.633756'), Decimal('102.063245'))  Maria Vitória Mendes
# 2  (Decimal('80.9854585'), Decimal('135.043616'))   Isabella Nascimento
# 3  (Decimal('67.6271835'), Decimal('-41.336778'))           Daria Boldù
# 4   (Decimal('39.336945'), Decimal('120.879401'))        Sandra Jenkins
#
#                              mail                     job  sex         race  \
# 0          xda-cunha@yahoo.com.br  Engenheiro aeronáutico  NaN  unspecified
# 1  catarinada-conceicao@gmail.com              Mãe social    F        black
# 2     maria-sophiasouza@ig.com.br                     NaN  NaN  unspecified
# 3               ngaleati@alice.it                     NaN  NaN  unspecified
# 4          danieljordan@yahoo.com             Fine artist  NaN  unspecified
#
#                                              address  birthdate  user_id
# 0  Condomínio de Silva, 16\r\nNovo Ouro Preto\r\n...        NaT      640
# 1  Campo Eloah Ribeiro, 66\r\nEstrela Do Oriente\... 1946-06-27     1222
# 2  Viela da Luz\r\nConjunto Santa Maria\r\n923541... 1940-12-01      298
# 3   Vicolo Sophia, 452 Piano 7\r\n26843, Meleti (LO) 1958-02-01      316
# 4  31740 Maria Stravenue Apt. 240\r\nLake Rodneyf... 1997-05-26     1992

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1594 entries, 0 to 2536
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   username          1594 non-null   object
#  1   residence         553 non-null    object
#  2   current_location  1509 non-null   object
#  3   name              1594 non-null   object
#  4   mail              1594 non-null   object
#  5   job               635 non-null    object
#  6   sex               777 non-null    object
#  7   race              1594 non-null   object
#  8   address           1354 non-null   object
#  9   birthdate         903 non-null    datetime64[ns]
#  10  user_id           1594 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 149.4+ KB

# %% [markdown]
# Po skúšaní spojiť session s product som prisšla k zisteniu, že product_ean sa nezhodujú, takže sa tie dva datasety nedajú spojiť. Nevidím žiadne logické riešenie ako by sa to dalo napraviť. Takže budem spájať a následne pracovať iba s users a sessions.

# %%
merged_data = pd.merge(sessions, users, on='user_id', how='left')
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10962 entries, 0 to 10961
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  10951 non-null  float64
#  1   screen_height                   10962 non-null  object
#  2   pct_input                       10951 non-null  float64
#  3   pct_scrandom                    10951 non-null  float64
#  4   pct_scroll_move                 10951 non-null  float64
#  5   pct_click_product_info          10951 non-null  float64
#  6   wild_mouse_duration             10951 non-null  float64
#  7   session_start                   10962 non-null  datetime64[ns]
#  8   total_load_time                 10962 non-null  float64
#  9   pct_click                       10951 non-null  float64
#  10  screen_width                    10962 non-null  object
#  11  pct_doubleclick                 10951 non-null  float64
#  12  product_ean                     10962 non-null  int64
#  13  pct_mouse_move                  10951 non-null  float64
#  14  user_id                         10962 non-null  int64
#  15  session_id                      10962 non-null  int64
#  16  pct_scroll_move_duration        10951 non-null  float64
#  17  ack                             10962 non-null  int32
#  18  scroll_move_total_rel_distance  10951 non-null  float64
#  19  page_activity_duration          10951 non-null  float64
#  20  mouse_move_total_rel_distance   10951 non-null  float64
#  21  browser_name                    10962 non-null  object
#  22  pct_rage_click                  10951 non-null  float64
#  23  session_duration                10962 non-null  float64
#  24  pct_mouse_click                 10951 non-null  float64
#  25  username                        6922 non-null   object
#  26  residence                       2464 non-null   object
#  27  current_location                6499 non-null   object
#  28  name                            6922 non-null   object
#  29  mail                            6922 non-null   object
#  30  job                             2817 non-null   object
#  31  sex                             3390 non-null   object
#  32  race                            6922 non-null   object
#  33  address                         5854 non-null   object
#  34  birthdate                       3876 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(17), int32(1), int64(3), object(12)
# memory usage: 2.9+ MB

# %% [markdown]
# *Ako prvé idem vymatať stlpce, ktoré sú mi zbytočné*</br>
# Vyrobila som si stlpec age (nahradila som aj chýbajúce hodnoty priemerom) pomocou stlpca birthday, ktorý následne budem vymazávať

# %%
merged_data['age'] = ((datetime.now() - merged_data['birthdate']).dt.days / 365.25)
merged_data['age'] = merged_data['age'].round()
mean_age = merged_data['age'].mean()
merged_data['age'].fillna(mean_age, inplace=True)
merged_data['age'] = merged_data['age'].round().astype(int)

merged_data.head()
# Out:
#    pct_wild_mouse screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175           600    2.02433      47.57172         77.67966
# 1        35.01962           768    2.73613      44.98978         40.38256
# 2        61.41151           800    2.30551      56.16179         29.32719
# 3        44.86510           600    4.67376      51.02882         57.35852
# 4        61.66559           800    6.29241      33.35663         50.05876
#
#    pct_click_product_info  wild_mouse_duration       session_start  \
# 0                50.06169             16.15405 2022-04-16 18:13:19
# 1                53.78582             16.44725 2022-09-07 09:34:07
# 2                61.74431             16.28032 2022-08-01 19:22:50
# 3                44.10727             16.97307 2020-03-28 06:00:21
# 4                36.03935             17.26692 2023-02-12 18:25:13
#
#    total_load_time  pct_click  ...  \
# 0          3.66109   15.21849  ...
# 1          3.06183   17.79744  ...
# 2          4.30491   16.56530  ...
# 3          2.66177   14.10738  ...
# 4          3.67287   19.04736  ...
#
#                                       residence  \
# 0                                           NaN
# 1                                           NaN
# 2  auch Schlauchinallee 0/2\r\n71393 Angermünde
# 3                                           NaN
# 4                                           NaN
#
#                                   current_location             name  \
# 0     (Decimal('65.429204'), Decimal('27.147097'))     Rebeca Silva
# 1  (Decimal('-65.9975475'), Decimal('-33.607602'))  Daria Boccaccio
# 2      (Decimal('53.467912'), Decimal('6.845211'))    Marisa Trubin
# 3    (Decimal('59.408055'), Decimal('129.747870'))     Igor Barbosa
# 4                                              NaN              NaN
#
#                       mail                         job  sex         race  \
# 0   danielsouza@bol.com.br    Lubrificador de máquinas  NaN  unspecified
# 1  francescapiane@alice.it  Sports development officer    F  unspecified
# 2       filiz70@hotmail.de                         NaN  NaN  unspecified
# 3  rezendesofia@uol.com.br                         NaN    M  unspecified
# 4                      NaN                         NaN  NaN          NaN
#
#                                              address  birthdate  age
# 0  Sítio da Luz, 777\r\nCarmo\r\n54487013 Silveir... 1988-07-17   35
# 1  Stretto Cammarata, 48 Appartamento 9\r\n44122,... 2016-12-07    7
# 2               Matthäistraße 376\r\n50173 Merseburg 1939-09-18   84
# 3  Trevo de Gonçalves, 246\r\nLuxemburgo\r\n79216...        NaT   60
# 4                                                NaN        NaT   60
#
# [5 rows x 36 columns]

# %%
if 'username' in merged_data.columns:
    merged_data.drop('username', axis='columns', inplace=True)
    print("vymazanie username")
if 'residence' in merged_data.columns:
    merged_data.drop('residence', axis='columns', inplace=True)
    print("vymazanie residence")
if 'current_location' in merged_data.columns:
    merged_data.drop('current_location', axis='columns', inplace=True)
    print("vymazanie current_location")
if 'name' in merged_data.columns:
    merged_data.drop('name', axis='columns', inplace=True)
    print("vymazanie name")
if 'mail' in merged_data.columns:
    merged_data.drop('mail', axis='columns', inplace=True)
    print("vymazanie mail")
if 'address' in merged_data.columns:
    merged_data.drop('address', axis='columns', inplace=True)
    print("vymazanie address")
if 'birthdate' in merged_data.columns:
    merged_data.drop('birthdate', axis='columns', inplace=True)
    print("vymazanie birthdate")
if 'session_start' in merged_data.columns:
    merged_data.drop('session_start', axis='columns', inplace=True)
    print("vymazanie session_start")
if 'sex' in merged_data.columns:
    merged_data.drop('sex', axis='columns', inplace=True)
    print("vymazanie sex")
merged_data.head()
# Out:
# vymazanie username
# vymazanie residence
# vymazanie current_location
# vymazanie name
# vymazanie mail
# vymazanie address
# vymazanie birthdate
# vymazanie session_start
# vymazanie sex
#    pct_wild_mouse screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175           600    2.02433      47.57172         77.67966
# 1        35.01962           768    2.73613      44.98978         40.38256
# 2        61.41151           800    2.30551      56.16179         29.32719
# 3        44.86510           600    4.67376      51.02882         57.35852
# 4        61.66559           800    6.29241      33.35663         50.05876
#
#    pct_click_product_info  wild_mouse_duration  total_load_time  pct_click  \
# 0                50.06169             16.15405          3.66109   15.21849
# 1                53.78582             16.44725          3.06183   17.79744
# 2                61.74431             16.28032          4.30491   16.56530
# 3                44.10727             16.97307          2.66177   14.10738
# 4                36.03935             17.26692          3.67287   19.04736
#
#   screen_width  ...  scroll_move_total_rel_distance  page_activity_duration  \
# 0         1366  ...                        13.31028                15.50704
# 1         1280  ...                        18.33657                15.76245
# 2         1280  ...                         7.24767                15.94806
# 3         1920  ...                         9.27093                17.21545
# 4         1024  ...                        19.71573                17.01892
#
#    mouse_move_total_rel_distance  browser_name  pct_rage_click  \
# 0                       16.78128        safari        73.88232
# 1                       16.67535       firefox        36.27018
# 2                       17.84916         opera        44.07316
# 3                       15.85436          edge        61.91555
# 4                       16.65385        chrome        21.36066
#
#    session_duration  pct_mouse_click                         job         race  \
# 0          93.50794              NaN    Lubrificador de máquinas  unspecified
# 1          83.05534         15.63971  Sports development officer  unspecified
# 2         212.16973         13.54653                         NaN  unspecified
# 3          62.13615         14.83673                         NaN  unspecified
# 4         157.60814         15.17088                         NaN          NaN
#
#    age
# 0   35
# 1    7
# 2   84
# 3   60
# 4   60
#
# [5 rows x 27 columns]

# %% [markdown]
# Vymazali sme hodnoty, ktoré su pre každého usera jedinečné a teda nám nič nepovedia o ack, teda username, residence, current_location, name, mail, address, birthdate a session_start. Dalej sme vymazali aj atribút sex, pretože má okolo 60% NaN hodnot a analyzovať ack na základe tohto atribútu by teda nebolo presné._start

# %%
merged_data['race'] = merged_data['race'].fillna('unspecified')
merged_data['job'] = merged_data['job'].fillna('unspecified')
merged_data.head()
# Out:
#    pct_wild_mouse screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175           600    2.02433      47.57172         77.67966
# 1        35.01962           768    2.73613      44.98978         40.38256
# 2        61.41151           800    2.30551      56.16179         29.32719
# 3        44.86510           600    4.67376      51.02882         57.35852
# 4        61.66559           800    6.29241      33.35663         50.05876
#
#    pct_click_product_info  wild_mouse_duration  total_load_time  pct_click  \
# 0                50.06169             16.15405          3.66109   15.21849
# 1                53.78582             16.44725          3.06183   17.79744
# 2                61.74431             16.28032          4.30491   16.56530
# 3                44.10727             16.97307          2.66177   14.10738
# 4                36.03935             17.26692          3.67287   19.04736
#
#   screen_width  ...  scroll_move_total_rel_distance  page_activity_duration  \
# 0         1366  ...                        13.31028                15.50704
# 1         1280  ...                        18.33657                15.76245
# 2         1280  ...                         7.24767                15.94806
# 3         1920  ...                         9.27093                17.21545
# 4         1024  ...                        19.71573                17.01892
#
#    mouse_move_total_rel_distance  browser_name  pct_rage_click  \
# 0                       16.78128        safari        73.88232
# 1                       16.67535       firefox        36.27018
# 2                       17.84916         opera        44.07316
# 3                       15.85436          edge        61.91555
# 4                       16.65385        chrome        21.36066
#
#    session_duration  pct_mouse_click                         job         race  \
# 0          93.50794              NaN    Lubrificador de máquinas  unspecified
# 1          83.05534         15.63971  Sports development officer  unspecified
# 2         212.16973         13.54653                 unspecified  unspecified
# 3          62.13615         14.83673                 unspecified  unspecified
# 4         157.60814         15.17088                 unspecified  unspecified
#
#    age
# 0   35
# 1    7
# 2   84
# 3   60
# 4   60
#
# [5 rows x 27 columns]

# %% [markdown]
# Doplnenie chýbajúcich hodnôt do objektových atribútov</br>
# Race má už v pôvodných dátach hodnotu 'unspecified' a v tomto kontexte je to isté ako NaN, tak všetky NaN hodnoty tým nahradíme. V atribúte jobs sa nachádza veľké množstvo NaN hodnôt a veľa rozličných druhov prác, takže by nebolo logické to nahradzovať napríklad pomerom prác, takže použijeme znova označenie 'unspecified'. Ziaden pocet NaN v spomýnaných atribútov vyššie nebol natoľko nízky, aby sme si ich mohli dovoliť vymazať. Ďalšie objektové atribúty nemajú NaN hodnoty

# %%
ce_ordinal = ce.OrdinalEncoder(cols=['race'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['job'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['browser_name'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['screen_height'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['screen_width'])
merged_data= ce_ordinal.fit_transform(merged_data)
merged_data.head()
# Out:
#    pct_wild_mouse  screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175              1    2.02433      47.57172         77.67966
# 1        35.01962              2    2.73613      44.98978         40.38256
# 2        61.41151              3    2.30551      56.16179         29.32719
# 3        44.86510              1    4.67376      51.02882         57.35852
# 4        61.66559              3    6.29241      33.35663         50.05876
#
#    pct_click_product_info  wild_mouse_duration  total_load_time  pct_click  \
# 0                50.06169             16.15405          3.66109   15.21849
# 1                53.78582             16.44725          3.06183   17.79744
# 2                61.74431             16.28032          4.30491   16.56530
# 3                44.10727             16.97307          2.66177   14.10738
# 4                36.03935             17.26692          3.67287   19.04736
#
#    screen_width  ...  scroll_move_total_rel_distance  page_activity_duration  \
# 0             1  ...                        13.31028                15.50704
# 1             2  ...                        18.33657                15.76245
# 2             2  ...                         7.24767                15.94806
# 3             3  ...                         9.27093                17.21545
# 4             4  ...                        19.71573                17.01892
#
#    mouse_move_total_rel_distance  browser_name  pct_rage_click  \
# 0                       16.78128             1        73.88232
# 1                       16.67535             2        36.27018
# 2                       17.84916             3        44.07316
# 3                       15.85436             4        61.91555
# 4                       16.65385             5        21.36066
#
#    session_duration  pct_mouse_click  job  race  age
# 0          93.50794              NaN    1     1   35
# 1          83.05534         15.63971    2     1    7
# 2         212.16973         13.54653    3     1   84
# 3          62.13615         14.83673    3     1   60
# 4         157.60814         15.17088    3     1   60
#
# [5 rows x 27 columns]

# %% [markdown]
# Následne objectové atribúty zmeníme na číselne pomocou Ordinal Encoding

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10962 entries, 0 to 10961
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  10951 non-null  float64
#  1   screen_height                   10962 non-null  int32
#  2   pct_input                       10951 non-null  float64
#  3   pct_scrandom                    10951 non-null  float64
#  4   pct_scroll_move                 10951 non-null  float64
#  5   pct_click_product_info          10951 non-null  float64
#  6   wild_mouse_duration             10951 non-null  float64
#  7   total_load_time                 10962 non-null  float64
#  8   pct_click                       10951 non-null  float64
#  9   screen_width                    10962 non-null  int32
#  10  pct_doubleclick                 10951 non-null  float64
#  11  product_ean                     10962 non-null  int64
#  12  pct_mouse_move                  10951 non-null  float64
#  13  user_id                         10962 non-null  int64
#  14  session_id                      10962 non-null  int64
#  15  pct_scroll_move_duration        10951 non-null  float64
#  16  ack                             10962 non-null  int32
#  17  scroll_move_total_rel_distance  10951 non-null  float64
#  18  page_activity_duration          10951 non-null  float64
#  19  mouse_move_total_rel_distance   10951 non-null  float64
#  20  browser_name                    10962 non-null  int32
#  21  pct_rage_click                  10951 non-null  float64
#  22  session_duration                10962 non-null  float64
#  23  pct_mouse_click                 10951 non-null  float64
#  24  job                             10962 non-null  int32
#  25  race                            10962 non-null  int32
#  26  age                             10962 non-null  int32
# dtypes: float64(17), int32(7), int64(3)
# memory usage: 2.0 MB

# %%
def deleteNaN(merged_data):
    for column in merged_data.columns:
        number_NaN=merged_data[column].isna().sum()
        if 0<number_NaN:
            merged_data = merged_data.dropna(subset=[column])
    return merged_data

# %%
def replaceNaNmean(merged_data):
    for column in merged_data.columns:
        number_NaN=merged_data[column].isna().sum()
        if 0<number_NaN:
           merged_data[column].fillna(merged_data[column].mean(), inplace=True)
    return merged_data

# %%
def replaceNaNmedian(merged_data):
    for column in merged_data.columns:
        number_NaN=merged_data[column].isna().sum()
        if 0<number_NaN:
           merged_data[column].fillna(merged_data[column].median(), inplace=True)
    return merged_data

# %%
#merged_data=deleteNaN(merged_data)
#merged_data=replaceNaNmean(merged_data)
merged_data=replaceNaNmedian(merged_data)

# %% [markdown]
# Vytvorili sme funkcie na vyriešenie NaN hodnôt. Môžeme si vybrať, či chceme ich vymazať, nahradiť priemerom alebo medianom.

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10962 entries, 0 to 10961
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  10962 non-null  float64
#  1   screen_height                   10962 non-null  int32
#  2   pct_input                       10962 non-null  float64
#  3   pct_scrandom                    10962 non-null  float64
#  4   pct_scroll_move                 10962 non-null  float64
#  5   pct_click_product_info          10962 non-null  float64
#  6   wild_mouse_duration             10962 non-null  float64
#  7   total_load_time                 10962 non-null  float64
#  8   pct_click                       10962 non-null  float64
#  9   screen_width                    10962 non-null  int32
#  10  pct_doubleclick                 10962 non-null  float64
#  11  product_ean                     10962 non-null  int64
#  12  pct_mouse_move                  10962 non-null  float64
#  13  user_id                         10962 non-null  int64
#  14  session_id                      10962 non-null  int64
#  15  pct_scroll_move_duration        10962 non-null  float64
#  16  ack                             10962 non-null  int32
#  17  scroll_move_total_rel_distance  10962 non-null  float64
#  18  page_activity_duration          10962 non-null  float64
#  19  mouse_move_total_rel_distance   10962 non-null  float64
#  20  browser_name                    10962 non-null  int32
#  21  pct_rage_click                  10962 non-null  float64
#  22  session_duration                10962 non-null  float64
#  23  pct_mouse_click                 10962 non-null  float64
#  24  job                             10962 non-null  int32
#  25  race                            10962 non-null  int32
#  26  age                             10962 non-null  int32
# dtypes: float64(17), int32(7), int64(3)
# memory usage: 2.0 MB

# %%
fig, ax = plt.subplots(figsize=(30, 20))
sns.boxplot(data=merged_data[['pct_wild_mouse', 'pct_input', 'pct_scrandom', 'pct_scroll_move', 'pct_click_product_info', 'wild_mouse_duration', 'total_load_time', 'pct_click']])
plt.show()
# Out:
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
fig, ax = plt.subplots(figsize=(30, 20))
sns.boxplot(data=merged_data[['pct_doubleclick', 'pct_mouse_move', 'pct_scroll_move_duration', 'scroll_move_total_rel_distance', 'page_activity_duration', 'mouse_move_total_rel_distance', 'pct_rage_click', 'pct_mouse_click']])
plt.show()
# Out:
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Na grafoch môžeme vidieť, že atribúty majú outlierov. Niektoré viac, niektoré menej. V grafe som obsiahla všetky atribúty, ktorých atribúty by bolo potrebné ošetriť na outlierov (ešte session duration, ale to som nedávala do grafu, lebo má veľké hodnoty oproti ostatným atribútom a nie je dobre vidieť potom ostatné)

# %%
#Funkcia prevzatá zo vzorových notebookov
def identify_outliers(a):
    lower = a.quantile(0.25) - 1.5 * stats.iqr(a)
    upper = a.quantile(0.75) + 1.5 * stats.iqr(a)
    
    return a[(a > upper) | (a < lower)]

# %%
def delete_outliers(merged_data):
    count=0
    pocet_zaznamov_na_zaciatku=merged_data.shape[0]
    for column in merged_data[['pct_doubleclick', 'pct_mouse_move', 'pct_scroll_move_duration', 'scroll_move_total_rel_distance', 'page_activity_duration', 'mouse_move_total_rel_distance', 'pct_rage_click', 'pct_mouse_click', 'pct_wild_mouse', 'pct_input', 'pct_scrandom', 'pct_scroll_move', 'pct_click_product_info', 'wild_mouse_duration', 'total_load_time', 'pct_click', 'session_duration']]:
        outliers = identify_outliers(merged_data[column])
        count+=outliers.count()
        merged_data=merged_data.drop(outliers.index)

    print(f'Počet vychýlených hodnôt je {count}')
    print(f'Percento zaznamov, ktore ostali v percentach: {merged_data.shape[0]*100/pocet_zaznamov_na_zaciatku}')
    return merged_data

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10962 entries, 0 to 10961
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  10962 non-null  float64
#  1   screen_height                   10962 non-null  int32
#  2   pct_input                       10962 non-null  float64
#  3   pct_scrandom                    10962 non-null  float64
#  4   pct_scroll_move                 10962 non-null  float64
#  5   pct_click_product_info          10962 non-null  float64
#  6   wild_mouse_duration             10962 non-null  float64
#  7   total_load_time                 10962 non-null  float64
#  8   pct_click                       10962 non-null  float64
#  9   screen_width                    10962 non-null  int32
#  10  pct_doubleclick                 10962 non-null  float64
#  11  product_ean                     10962 non-null  int64
#  12  pct_mouse_move                  10962 non-null  float64
#  13  user_id                         10962 non-null  int64
#  14  session_id                      10962 non-null  int64
#  15  pct_scroll_move_duration        10962 non-null  float64
#  16  ack                             10962 non-null  int32
#  17  scroll_move_total_rel_distance  10962 non-null  float64
#  18  page_activity_duration          10962 non-null  float64
#  19  mouse_move_total_rel_distance   10962 non-null  float64
#  20  browser_name                    10962 non-null  int32
#  21  pct_rage_click                  10962 non-null  float64
#  22  session_duration                10962 non-null  float64
#  23  pct_mouse_click                 10962 non-null  float64
#  24  job                             10962 non-null  int32
#  25  race                            10962 non-null  int32
#  26  age                             10962 non-null  int32
# dtypes: float64(17), int32(7), int64(3)
# memory usage: 2.0 MB

# %%
merged_data = delete_outliers(merged_data)
merged_data.info()
# Out:
# Počet vychýlených hodnôt je 2014
# Percento zaznamov, ktore ostali v percentach: 81.6274402481299
# <class 'pandas.core.frame.DataFrame'>
# Index: 8948 entries, 0 to 10961
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  8948 non-null   float64
#  1   screen_height                   8948 non-null   int32
#  2   pct_input                       8948 non-null   float64
#  3   pct_scrandom                    8948 non-null   float64
#  4   pct_scroll_move                 8948 non-null   float64
#  5   pct_click_product_info          8948 non-null   float64
#  6   wild_mouse_duration             8948 non-null   float64
#  7   total_load_time                 8948 non-null   float64
#  8   pct_click                       8948 non-null   float64
#  9   screen_width                    8948 non-null   int32
#  10  pct_doubleclick                 8948 non-null   float64
#  11  product_ean                     8948 non-null   int64
#  12  pct_mouse_move                  8948 non-null   float64
#  13  user_id                         8948 non-null   int64
#  14  session_id                      8948 non-null   int64
#  15  pct_scroll_move_duration        8948 non-null   float64
#  16  ack                             8948 non-null   int32
#  17  scroll_move_total_rel_distance  8948 non-null   float64
#  18  page_activity_duration          8948 non-null   float64
#  19  mouse_move_total_rel_distance   8948 non-null   float64
#  20  browser_name                    8948 non-null   int32
#  21  pct_rage_click                  8948 non-null   float64
#  22  session_duration                8948 non-null   float64
#  23  pct_mouse_click                 8948 non-null   float64
#  24  job                             8948 non-null   int32
#  25  race                            8948 non-null   int32
#  26  age                             8948 non-null   int32
# dtypes: float64(17), int32(7), int64(3)
# memory usage: 1.7 MB

# %% [markdown]
# Vymazanie outlierov, zistili sme, že skoro 20% dát sme stratili

# %%
def delete_outliers_quantile(merged_data):
    count=0
    for column in merged_data[['pct_doubleclick', 'pct_mouse_move', 'pct_scroll_move_duration', 'scroll_move_total_rel_distance', 'page_activity_duration', 'mouse_move_total_rel_distance', 'pct_rage_click', 'pct_mouse_click', 'pct_wild_mouse', 'pct_input', 'pct_scrandom', 'pct_scroll_move', 'pct_click_product_info', 'wild_mouse_duration', 'total_load_time', 'pct_click', 'session_duration']]:
        outliers = identify_outliers(merged_data[column])
        lower_q = merged_data[column].quantile(0.05)
        uper_q = merged_data[column].quantile(0.95)
        count+=outliers.count()
        merged_data[column] = merged_data[column].clip(lower_q, uper_q)
        
    print(f'Počet zmenenych hodnôt je {count}')
    return merged_data

# %%
#merged_data = delete_outliers_quantile(merged_data)
#merged_data.info()

# %% [markdown]
# Alternatíva pre outlierov je, že ich nahradím hraničnými hodnotami, teda quantilom 0.05 alebo 0.95

# %% [markdown]
# # 2. Predspracovanie dat

# %% [markdown]
# We split the data into 2 different sets of data one will be for training and the other part will be for testing the predicted results. The training part will be 80% of the data and the testing part will be the 20% of the complete data.

# %%
features = merged_data.drop('ack', axis=1)
target = merged_data['ack']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

X_train
# Out:
#       pct_wild_mouse  screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 9326        57.65601              5    1.16775      31.05366         75.03575
# 6986        53.20554              1    4.03700      42.57398         66.77075
# 3621        32.08738              2    1.12728      45.43745         52.70110
# 3637        59.44242              4    1.22600      42.07027         27.92109
# 9865        79.27181              5    0.68271      76.89111         61.08636
# ...              ...            ...        ...           ...              ...
# 7028        37.69758              5    6.67999      35.91832         36.30834
# 6369        47.32132              3    5.07519      35.73671         55.40893
# 6603        65.31653              6    0.45117      63.27280         53.17940
# 1057        78.75737              7    0.48053      45.92923         50.20358
# 8910        54.80246              1    7.81183      45.18146         50.08293
#
#       pct_click_product_info  wild_mouse_duration  total_load_time  pct_click  \
# 9326                40.50160             15.62633          1.93104   14.51268
# 6986                28.88212             16.82874          5.17281   18.12052
# 3621                34.58205             15.59301          5.03297   18.33731
# 3637                27.66239             15.67245          5.70022   17.96591
# 9865                22.03654             15.12626         10.24121   20.48074
# ...                      ...                  ...              ...        ...
# 7028                45.42789             17.32608          3.63522   19.52320
# 6369                62.39464             17.05438          0.94554   17.66598
# 6603                54.45418             14.75556          3.77690   17.53160
# 1057                49.03628             14.81084          2.30610   13.80669
# 8910                47.23170             17.48123          9.42716   17.55555
#
#       screen_width  ...  scroll_move_total_rel_distance  \
# 9326             5  ...                         9.90963
# 6986             2  ...                        13.72969
# 3621             2  ...                        13.87142
# 3637             7  ...                        15.78900
# 9865             3  ...                        17.32169
# ...            ...  ...                             ...
# 7028             6  ...                        15.92570
# 6369             2  ...                        14.19886
# 6603             4  ...                        11.32240
# 1057             3  ...                        13.23998
# 8910             2  ...                        19.36016
#
#       page_activity_duration  mouse_move_total_rel_distance  browser_name  \
# 9326                15.77853                       13.28226             3
# 6986                17.33340                       17.15487             5
# 3621                15.33240                       19.53838             4
# 3637                16.64294                       18.89060             2
# 9865                16.81626                       19.61759             4
# ...                      ...                            ...           ...
# 7028                16.15766                       18.51539             5
# 6369                15.58098                       19.56023             4
# 6603                15.53329                       18.24384             4
# 1057                16.58841                       13.74976             5
# 8910                16.56226                       19.93663             5
#
#       pct_rage_click  session_duration  pct_mouse_click  job  race  age
# 9326        23.49009          64.32872         11.82479    3     1   84
# 6986        43.50684         165.46769         15.66504    3     1   60
# 3621        52.84745          50.53015         13.69734  120     1   12
# 3637        49.14594         186.58193         14.76433    3     1   60
# 9865        32.02144         200.62330         16.36232    3     1   60
# ...              ...               ...              ...  ...   ...  ...
# 7028        55.63218         112.72287         14.79973    3     1   60
# 6369        45.32908         184.86381         15.03829    3     1   60
# 6603        73.10340         165.81022         10.77610    3     1   60
# 1057        56.71765          84.42132         15.73600    3     1   91
# 8910        51.50636         186.25222         16.25724  191     1   60
#
# [7158 rows x 26 columns]

# %% [markdown]
# ### Encoding

# %% [markdown]
# All useful text columns were encoded in the previous section using ordinal encoding where different text categories were encoded into numbers where each category was given a unique number.

# %% [markdown]
# ### Skalovanie

# %% [markdown]
# We normalize the data using the MinMaxScaler. We use the MinMaxScaler because this scaler provides uniform scaling and ensures that no single feature dominates the model due to its scale. Also, it preserver the relationships among the original data points.

# %%
scaler = MinMaxScaler()
graph = pyplot.hist(X_train, bins=25)
graph.index
X_scaled = scaler.fit_transform(X_train)

# %%
graph = pyplot.hist(X_scaled, bins=25)
graph.index
# Out:
# <function tuple.index(value, start=0, stop=9223372036854775807, /)>

# %% [markdown]
# ### Standard scaling

# %% [markdown]
# We use standard scaling to make the data more Gaussian like, but the extreme values will still persisit, this will have to be fixed in the next step.

# %%
# scaler = RobustScaler()
# X_scaled = scaler.fit_transform(X_scaled) 
# pyplot.hist(X_scaled, bins=25)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_scaled)
graph = pyplot.hist(X_scaled, bins=25)
graph.index
# Out:
# <function tuple.index(value, start=0, stop=9223372036854775807, /)>

# %% [markdown]
# ### Making data distribution more normal

# %%
power = PowerTransformer(method='yeo-johnson', standardize=True) 
X_new = power.fit_transform(X_scaled)
graph = pyplot.hist(X_new, bins=25)
graph.index
# Out:
# <function tuple.index(value, start=0, stop=9223372036854775807, /)>

# %% [markdown]
# We can see on the graph that there are big extreme values on the side, we want to make our data more uniform using the PowerTransformaer and the yeo-johnson method. This will make the distribution of our data more Gaussian.

# %% [markdown]
# ### Quantile transform

# %% [markdown]
# <!-- We are going to use QuantileTransform to reduce the skewness of the original data. This method also helps handlig outliers by making extreme values less influential. -->

# %%
# selector = VarianceThreshold(threshold=(1.0))
# pyplot.hist(X_new, bins=5)
# X_new = selector.fit_transform(X_new)
# qt = QuantileTransformer(n_quantiles=10, random_state=0)
# X_new = qt.fit_transform(X_scaled)
# pyplot.hist(X_new, bins=25)

# %% [markdown]
# ### Feature selection

# %%
transform = SelectKBest(mutual_info_regression, k=10)
transform.fit_transform( X_new, y_train)
result=pd.DataFrame({'column_name':X_train.columns, 'column_score':transform.scores_})
result.sort_values('column_score', ascending=False).head(10)
# Out:
#                        column_name  column_score
# 18   mouse_move_total_rel_distance      0.129512
# 8                        pct_click      0.124795
# 12                  pct_mouse_move      0.110790
# 16  scroll_move_total_rel_distance      0.022119
# 25                             age      0.014398
# 1                    screen_height      0.013372
# 9                     screen_width      0.011276
# 19                    browser_name      0.007756
# 22                 pct_mouse_click      0.007537
# 20                  pct_rage_click      0.005552

# %% [markdown]
# Podľa výsledkov môžeme vidieť, že prvé 3 atribúty majú omnoho vyššie skore ako ostatné, štvrtý má tiež vyššie oproti ostatným, ale porovnateľne nižsie ako spomínané 3 atribúty

# %%
transform2 = SelectKBest(f_regression, k=10)
transform2.fit_transform( X_new, y_train)
result2=pd.DataFrame({'column_name':X_train.columns, 'column_score':transform2.scores_})
result2.sort_values('column_score', ascending=False).head(10)
# Out:
#                        column_name  column_score
# 8                        pct_click   1282.033129
# 18   mouse_move_total_rel_distance   1085.188829
# 12                  pct_mouse_move   1080.242181
# 16  scroll_move_total_rel_distance     30.986683
# 22                 pct_mouse_click     10.386740
# 21                session_duration      7.242011
# 10                 pct_doubleclick      2.685884
# 4                  pct_scroll_move      2.451753
# 7                  total_load_time      2.336056
# 14                      session_id      1.765228

# %% [markdown]
# Podľa výsledkov môžeme vidieť, že prvé 3 atribúty majú omnoho vyššie skore ako ostatné, štvrtý má tiež vyššie oproti ostatným, ale porovnateľne nižsie ako spomínané 3 atribúty

# %%
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit( X_new, y_train)
selector = SelectFromModel(estimator=lsvc, prefit=True)
pd.DataFrame({'attr':X_train.columns, 'score':lsvc.coef_[0]}).sort_values('score', ascending=False).head(10)
# Out:
#                               attr     score
# 15        pct_scroll_move_duration  0.452978
# 8                        pct_click  0.442204
# 22                 pct_mouse_click  0.210643
# 18   mouse_move_total_rel_distance  0.163740
# 10                 pct_doubleclick  0.116683
# 4                  pct_scroll_move  0.013099
# 21                session_duration  0.012542
# 11                     product_ean  0.000000
# 16  scroll_move_total_rel_distance  0.000000
# 14                      session_id  0.000000

# %% [markdown]
# Podľa výsledkov môžeme vidieť, že prvé 2 atribúty majú omnoho vyššie skore ako ostatné, tretí, štvrtý a piaty má tiež vyššie oproti ostatným, ale porovnateľne nižsie ako spomínané 2 atribúty

# %%
selector = SelectFromModel(estimator=LogisticRegression()).fit( X_new, y_train)
result3=pd.DataFrame({'column_name':X_train.columns, 'column_score':selector.estimator_.coef_[0]})
result3.sort_values('column_score', ascending=False).head(10)
# Out:
#                        column_name  column_score
# 15        pct_scroll_move_duration      2.622646
# 16  scroll_move_total_rel_distance      2.455874
# 8                        pct_click      0.454667
# 18   mouse_move_total_rel_distance      0.201012
# 2                        pct_input      0.113102
# 4                  pct_scroll_move      0.060609
# 21                session_duration      0.053293
# 20                  pct_rage_click      0.019794
# 14                      session_id      0.019319
# 3                     pct_scrandom      0.005988

# %% [markdown]
# Podľa výsledkov môžeme vidieť, že prvé 2 atribúty majú omnoho vyššie skore ako ostatné, tretí, prípadne štvrtý má tiež vyššie oproti ostatným, ale porovnateľne nižsie ako spomínané 2 atribúty

# %% [markdown]
# Z výsledkov môžeme vidieť, že najdôležitejšie atribúty sú pct_clic a mouse_move_total_rel_distance, kedže mali vo všetkých výsledkoch výrazne vyššie skore. Do úvahy môžem zobrať aj atribúť scroll_move_total_rel_distance, kedže tiež mal vyššie skore v vačšine testov. Poradie by som určila takéto:
# 1. pct_clic
# 2.  mouse_move_total_rel_distance
# 3.  scroll_move_total_rel_distance
