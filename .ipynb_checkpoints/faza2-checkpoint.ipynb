# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from datetime import datetime
import category_encoders as ce

# %%
products = pd.read_csv("data/product.csv", sep='\t')
sessions = pd.read_csv("data/session.csv", sep='\t')
users = pd.read_csv("data/user.csv", sep='\t')

# %% [markdown]
# Vyriešené chyby z predchádzajúcej fázy

# %%
users['race'] = users['race'].fillna('unspecified')
users['birthdate'] = pd.to_datetime(users['birthdate'], errors='coerce')
sessions['ack']=sessions['ack'].astype(int)
duplikatne_riadky = sessions[sessions.duplicated()]
sessions.drop_duplicates(inplace=True)
sessions['session_start'] = pd.to_datetime(sessions['session_start'], errors='coerce')

# %%
products.head()
# Out:
#   code             location       store_name    product_ean
# 0   HR        Europe/Zagreb            Split  3618641987900
# 1   CN        Asia/Shanghai           Heyuan   890698872559
# 2   NL     Europe/Amsterdam        Barneveld  2447491624236
# 3   MX  America/Mexico_City           Tuxtla  2920947188549
# 4   US     America/New_York  Sun City Center  4869841703558

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14962 entries, 0 to 14961
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   code         14948 non-null  object
#  1   location     14962 non-null  object
#  2   store_name   14962 non-null  object
#  3   product_ean  14962 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 467.7+ KB

# %%
sessions.head()
# Out:
#    pct_wild_mouse screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175           600    2.02433      47.57172         77.67966
# 1        35.01962           768    2.73613      44.98978         40.38256
# 2        61.41151           800    2.30551      56.16179         29.32719
# 3        44.86510           600    4.67376      51.02882         57.35852
# 4        61.66559           800    6.29241      33.35663         50.05876
#
#    pct_click_product_info  wild_mouse_duration       session_start  \
# 0                50.06169             16.15405 2022-04-16 18:13:19
# 1                53.78582             16.44725 2022-09-07 09:34:07
# 2                61.74431             16.28032 2022-08-01 19:22:50
# 3                44.10727             16.97307 2020-03-28 06:00:21
# 4                36.03935             17.26692 2023-02-12 18:25:13
#
#    total_load_time  pct_click  ... session_id  pct_scroll_move_duration  ack  \
# 0          3.66109   15.21849  ...     341891                  17.64845    0
# 1          3.06183   17.79744  ...    1302699                  16.90542    1
# 2          4.30491   16.56530  ...    1346090                  20.42301    1
# 3          2.66177   14.10738  ...     320000                  19.13251    0
# 4          3.67287   19.04736  ...     291366                  13.65667    0
#
#    scroll_move_total_rel_distance  page_activity_duration  \
# 0                        13.31028                15.50704
# 1                        18.33657                15.76245
# 2                         7.24767                15.94806
# 3                         9.27093                17.21545
# 4                        19.71573                17.01892
#
#    mouse_move_total_rel_distance  browser_name  pct_rage_click  \
# 0                       16.78128        safari        73.88232
# 1                       16.67535       firefox        36.27018
# 2                       17.84916         opera        44.07316
# 3                       15.85436          edge        61.91555
# 4                       16.65385        chrome        21.36066
#
#    session_duration  pct_mouse_click
# 0          93.50794              NaN
# 1          83.05534         15.63971
# 2         212.16973         13.54653
# 3          62.13615         14.83673
# 4         157.60814         15.17088
#
# [5 rows x 25 columns]

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10962 entries, 0 to 11093
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  10951 non-null  float64
#  1   screen_height                   10962 non-null  object
#  2   pct_input                       10951 non-null  float64
#  3   pct_scrandom                    10951 non-null  float64
#  4   pct_scroll_move                 10951 non-null  float64
#  5   pct_click_product_info          10951 non-null  float64
#  6   wild_mouse_duration             10951 non-null  float64
#  7   session_start                   10962 non-null  datetime64[ns]
#  8   total_load_time                 10962 non-null  float64
#  9   pct_click                       10951 non-null  float64
#  10  screen_width                    10962 non-null  object
#  11  pct_doubleclick                 10951 non-null  float64
#  12  product_ean                     10962 non-null  int64
#  13  pct_mouse_move                  10951 non-null  float64
#  14  user_id                         10962 non-null  int64
#  15  session_id                      10962 non-null  int64
#  16  pct_scroll_move_duration        10951 non-null  float64
#  17  ack                             10962 non-null  int32
#  18  scroll_move_total_rel_distance  10951 non-null  float64
#  19  page_activity_duration          10951 non-null  float64
#  20  mouse_move_total_rel_distance   10951 non-null  float64
#  21  browser_name                    10962 non-null  object
#  22  pct_rage_click                  10951 non-null  float64
#  23  session_duration                10962 non-null  float64
#  24  pct_mouse_click                 10951 non-null  float64
# dtypes: datetime64[ns](1), float64(17), int32(1), int64(3), object(3)
# memory usage: 2.1+ MB

# %%
users.head()
# Out:
#             username residence  \
# 0  gabrieladas-neves       NaN
# 1      ferreirajulia       NaN
# 2          isadora80       NaN
# 3          adriana04       NaN
# 4          kellygreg       NaN
#
#                                  current_location                  name  \
# 0   (Decimal('-37.802134'), Decimal('79.453092'))        Sabrina da Luz
# 1    (Decimal('4.633756'), Decimal('102.063245'))  Maria Vitória Mendes
# 2  (Decimal('80.9854585'), Decimal('135.043616'))   Isabella Nascimento
# 3  (Decimal('67.6271835'), Decimal('-41.336778'))           Daria Boldù
# 4   (Decimal('39.336945'), Decimal('120.879401'))        Sandra Jenkins
#
#                              mail                     job  sex         race  \
# 0          xda-cunha@yahoo.com.br  Engenheiro aeronáutico  NaN  unspecified
# 1  catarinada-conceicao@gmail.com              Mãe social    F        black
# 2     maria-sophiasouza@ig.com.br                     NaN  NaN  unspecified
# 3               ngaleati@alice.it                     NaN  NaN  unspecified
# 4          danieljordan@yahoo.com             Fine artist  NaN  unspecified
#
#                                              address  birthdate  user_id
# 0  Condomínio de Silva, 16\r\nNovo Ouro Preto\r\n...        NaT      640
# 1  Campo Eloah Ribeiro, 66\r\nEstrela Do Oriente\... 1946-06-27     1222
# 2  Viela da Luz\r\nConjunto Santa Maria\r\n923541... 1940-12-01      298
# 3   Vicolo Sophia, 452 Piano 7\r\n26843, Meleti (LO) 1958-02-01      316
# 4  31740 Maria Stravenue Apt. 240\r\nLake Rodneyf... 1997-05-26     1992

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2538 entries, 0 to 2537
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   username          2538 non-null   object
#  1   residence         888 non-null    object
#  2   current_location  2411 non-null   object
#  3   name              2538 non-null   object
#  4   mail              2538 non-null   object
#  5   job               1015 non-null   object
#  6   sex               1269 non-null   object
#  7   race              2538 non-null   object
#  8   address           2157 non-null   object
#  9   birthdate         1396 non-null   datetime64[ns]
#  10  user_id           2538 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 218.2+ KB

# %% [markdown]
# Po skúšaní spojiť session s product som prisšla k zisteniu, že product_ean sa nezhodujú, takže sa tie dva datasety nedajú spojiť. Nevidím žiadne logické riešenie ako by sa to dalo napraviť. Takže budem spájať a následne pracovať iba s users a sessions.

# %%
merged_data = pd.merge(sessions, users, on='user_id', how='left')
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15109 entries, 0 to 15108
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  15097 non-null  float64
#  1   screen_height                   15109 non-null  object
#  2   pct_input                       15097 non-null  float64
#  3   pct_scrandom                    15095 non-null  float64
#  4   pct_scroll_move                 15095 non-null  float64
#  5   pct_click_product_info          15095 non-null  float64
#  6   wild_mouse_duration             15091 non-null  float64
#  7   session_start                   15109 non-null  datetime64[ns]
#  8   total_load_time                 15109 non-null  float64
#  9   pct_click                       15094 non-null  float64
#  10  screen_width                    15109 non-null  object
#  11  pct_doubleclick                 15092 non-null  float64
#  12  product_ean                     15109 non-null  int64
#  13  pct_mouse_move                  15096 non-null  float64
#  14  user_id                         15109 non-null  int64
#  15  session_id                      15109 non-null  int64
#  16  pct_scroll_move_duration        15097 non-null  float64
#  17  ack                             15109 non-null  int32
#  18  scroll_move_total_rel_distance  15097 non-null  float64
#  19  page_activity_duration          15093 non-null  float64
#  20  mouse_move_total_rel_distance   15091 non-null  float64
#  21  browser_name                    15109 non-null  object
#  22  pct_rage_click                  15092 non-null  float64
#  23  session_duration                15109 non-null  float64
#  24  pct_mouse_click                 15093 non-null  float64
#  25  username                        11069 non-null  object
#  26  residence                       3911 non-null   object
#  27  current_location                10462 non-null  object
#  28  name                            11069 non-null  object
#  29  mail                            11069 non-null  object
#  30  job                             4534 non-null   object
#  31  sex                             5587 non-null   object
#  32  race                            11069 non-null  object
#  33  address                         9382 non-null   object
#  34  birthdate                       6067 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(17), int32(1), int64(3), object(12)
# memory usage: 4.0+ MB

# %% [markdown]
# *Ako prvé idem vymatať stlpce, ktoré sú mi zbytočné*</br>
# Vyrobila som si stlpec age (nahradila som aj chýbajúce hodnoty priemerom) pomocou stlpca birthday, ktorý následne budem vymazávať

# %%
merged_data['age'] = ((datetime.now() - merged_data['birthdate']).dt.days / 365.25)
merged_data['age'] = merged_data['age'].round()
mean_age = merged_data['age'].mean()
merged_data['age'].fillna(mean_age, inplace=True)
merged_data['age'] = merged_data['age'].round().astype(int)

merged_data.head()
# Out:
#    pct_wild_mouse screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175           600    2.02433      47.57172         77.67966
# 1        33.93175           600    2.02433      47.57172         77.67966
# 2        35.01962           768    2.73613      44.98978         40.38256
# 3        35.01962           768    2.73613      44.98978         40.38256
# 4        35.01962           768    2.73613      44.98978         40.38256
#
#    pct_click_product_info  wild_mouse_duration       session_start  \
# 0                50.06169             16.15405 2022-04-16 18:13:19
# 1                50.06169             16.15405 2022-04-16 18:13:19
# 2                53.78582             16.44725 2022-09-07 09:34:07
# 3                53.78582             16.44725 2022-09-07 09:34:07
# 4                53.78582             16.44725 2022-09-07 09:34:07
#
#    total_load_time  pct_click  ...  \
# 0          3.66109   15.21849  ...
# 1          3.66109   15.21849  ...
# 2          3.06183   17.79744  ...
# 3          3.06183   17.79744  ...
# 4          3.06183   17.79744  ...
#
#                                       residence  \
# 0                                           NaN
# 1  69785 Brenda Hollow\r\nWest Brandi, AL 29408
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                    current_location             name  \
# 0      (Decimal('65.429204'), Decimal('27.147097'))     Rebeca Silva
# 1     (Decimal('-74.5507745'), Decimal('2.339005'))   Patrick Vargas
# 2   (Decimal('-65.9975475'), Decimal('-33.607602'))  Daria Boccaccio
# 3  (Decimal('-59.9246355'), Decimal('-119.343543'))            西村 陽子
# 4    (Decimal('40.4064215'), Decimal('-76.044164'))       Timm Klemm
#
#                       mail                         job  sex         race  \
# 0   danielsouza@bol.com.br    Lubrificador de máquinas  NaN  unspecified
# 1       qjimenez@yahoo.com                         NaN  NaN  unspecified
# 2  francescapiane@alice.it  Sports development officer    F  unspecified
# 3         iikeda@yahoo.com                      高等学校教員    F  unspecified
# 4         vincent64@aol.de               Programmierer  NaN        black
#
#                                              address  birthdate  age
# 0  Sítio da Luz, 777\r\nCarmo\r\n54487013 Silveir... 1988-07-17   35
# 1  0012 Gardner Lock Apt. 697\r\nLake Connorville...        NaT   59
# 2  Stretto Cammarata, 48 Appartamento 9\r\n44122,... 2016-12-07    7
# 3                      熊本県八千代市元浅草40丁目9番2号 山中新田パレス114 1951-05-30   72
# 4            Kaspar-Heydrich-Platz 1\r\n02078 Kyritz 1939-05-05   85
#
# [5 rows x 36 columns]

# %%
if 'username' in merged_data.columns:
    merged_data.drop('username', axis='columns', inplace=True)
    print("vymazanie username")
if 'residence' in merged_data.columns:
    merged_data.drop('residence', axis='columns', inplace=True)
    print("vymazanie residence")
if 'current_location' in merged_data.columns:
    merged_data.drop('current_location', axis='columns', inplace=True)
    print("vymazanie current_location")
if 'name' in merged_data.columns:
    merged_data.drop('name', axis='columns', inplace=True)
    print("vymazanie name")
if 'mail' in merged_data.columns:
    merged_data.drop('mail', axis='columns', inplace=True)
    print("vymazanie mail")
if 'address' in merged_data.columns:
    merged_data.drop('address', axis='columns', inplace=True)
    print("vymazanie address")
if 'birthdate' in merged_data.columns:
    merged_data.drop('birthdate', axis='columns', inplace=True)
    print("vymazanie birthdate")
if 'session_start' in merged_data.columns:
    merged_data.drop('session_start', axis='columns', inplace=True)
    print("vymazanie session_start")
merged_data.head()
# Out:
# vymazanie username
# vymazanie residence
# vymazanie current_location
# vymazanie name
# vymazanie mail
# vymazanie address
# vymazanie birthdate
# vymazanie session_start
#    pct_wild_mouse screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175           600    2.02433      47.57172         77.67966
# 1        33.93175           600    2.02433      47.57172         77.67966
# 2        35.01962           768    2.73613      44.98978         40.38256
# 3        35.01962           768    2.73613      44.98978         40.38256
# 4        35.01962           768    2.73613      44.98978         40.38256
#
#    pct_click_product_info  wild_mouse_duration  total_load_time  pct_click  \
# 0                50.06169             16.15405          3.66109   15.21849
# 1                50.06169             16.15405          3.66109   15.21849
# 2                53.78582             16.44725          3.06183   17.79744
# 3                53.78582             16.44725          3.06183   17.79744
# 4                53.78582             16.44725          3.06183   17.79744
#
#   screen_width  ...  page_activity_duration  mouse_move_total_rel_distance  \
# 0         1366  ...                15.50704                       16.78128
# 1         1366  ...                15.50704                       16.78128
# 2         1280  ...                15.76245                       16.67535
# 3         1280  ...                15.76245                       16.67535
# 4         1280  ...                15.76245                       16.67535
#
#    browser_name  pct_rage_click  session_duration  pct_mouse_click  \
# 0        safari        73.88232          93.50794              NaN
# 1        safari        73.88232          93.50794              NaN
# 2       firefox        36.27018          83.05534         15.63971
# 3       firefox        36.27018          83.05534         15.63971
# 4       firefox        36.27018          83.05534         15.63971
#
#                           job  sex         race  age
# 0    Lubrificador de máquinas  NaN  unspecified   35
# 1                         NaN  NaN  unspecified   59
# 2  Sports development officer    F  unspecified    7
# 3                      高等学校教員    F  unspecified   72
# 4               Programmierer  NaN        black   85
#
# [5 rows x 28 columns]

# %% [markdown]
# Doplnenie chýbajúcich hodnôt do objektových atribútov</br>
# Race má už v pôvodných dátach hodnotu 'unspecified' a v tomto kontexte je to isté ako NaN, tak všetky NaN hodnoty tým nahradíme. V atribúte jobs sa nachádza veľké množstvo NaN hodnôt a veľa rozličných druhov prác, takže by nebolo logické to nahradzovať napríklad pomerom prác, takže použijeme znova označenie 'unspecified'. Pri atribúte sex by bolo najlogickejšie nahradiť NaN hodnoty pomerom F a M, ktoré sa už v dátach nachádzajú, však ked sa bližšie pozrieme na dáta, tak zistíme, že až okolo 60% je NaN hodnôt, takže by nahradenie pomocou pomeru nebolo asi najlogickejšie, takže zvolím označenie 'U', čo znamená 'unspecified'. Ziaden pocet NaN v spomýnaných atribútov vyššie nebol natoľko nízky, aby sme si ich mohli dovoliť vymazať. Ďalšie objektové atribúty nemajú NaN hodnoty

# %%
merged_data['race'] = merged_data['race'].fillna('unspecified')
merged_data['job'] = merged_data['job'].fillna('unspecified')
merged_data['sex'] = merged_data['sex'].fillna('U')
merged_data.head()
# Out:
#    pct_wild_mouse screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175           600    2.02433      47.57172         77.67966
# 1        33.93175           600    2.02433      47.57172         77.67966
# 2        35.01962           768    2.73613      44.98978         40.38256
# 3        35.01962           768    2.73613      44.98978         40.38256
# 4        35.01962           768    2.73613      44.98978         40.38256
#
#    pct_click_product_info  wild_mouse_duration  total_load_time  pct_click  \
# 0                50.06169             16.15405          3.66109   15.21849
# 1                50.06169             16.15405          3.66109   15.21849
# 2                53.78582             16.44725          3.06183   17.79744
# 3                53.78582             16.44725          3.06183   17.79744
# 4                53.78582             16.44725          3.06183   17.79744
#
#   screen_width  ...  page_activity_duration  mouse_move_total_rel_distance  \
# 0         1366  ...                15.50704                       16.78128
# 1         1366  ...                15.50704                       16.78128
# 2         1280  ...                15.76245                       16.67535
# 3         1280  ...                15.76245                       16.67535
# 4         1280  ...                15.76245                       16.67535
#
#    browser_name  pct_rage_click  session_duration  pct_mouse_click  \
# 0        safari        73.88232          93.50794              NaN
# 1        safari        73.88232          93.50794              NaN
# 2       firefox        36.27018          83.05534         15.63971
# 3       firefox        36.27018          83.05534         15.63971
# 4       firefox        36.27018          83.05534         15.63971
#
#                           job  sex         race  age
# 0    Lubrificador de máquinas    U  unspecified   35
# 1                 unspecified    U  unspecified   59
# 2  Sports development officer    F  unspecified    7
# 3                      高等学校教員    F  unspecified   72
# 4               Programmierer    U        black   85
#
# [5 rows x 28 columns]

# %%
ce_ordinal = ce.OrdinalEncoder(cols=['sex'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['race'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['job'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['browser_name'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['screen_height'])
merged_data= ce_ordinal.fit_transform(merged_data)
ce_ordinal = ce.OrdinalEncoder(cols=['screen_width'])
merged_data= ce_ordinal.fit_transform(merged_data)
merged_data.head()
# Out:
#    pct_wild_mouse  screen_height  pct_input  pct_scrandom  pct_scroll_move  \
# 0        33.93175              1    2.02433      47.57172         77.67966
# 1        33.93175              1    2.02433      47.57172         77.67966
# 2        35.01962              2    2.73613      44.98978         40.38256
# 3        35.01962              2    2.73613      44.98978         40.38256
# 4        35.01962              2    2.73613      44.98978         40.38256
#
#    pct_click_product_info  wild_mouse_duration  total_load_time  pct_click  \
# 0                50.06169             16.15405          3.66109   15.21849
# 1                50.06169             16.15405          3.66109   15.21849
# 2                53.78582             16.44725          3.06183   17.79744
# 3                53.78582             16.44725          3.06183   17.79744
# 4                53.78582             16.44725          3.06183   17.79744
#
#    screen_width  ...  page_activity_duration  mouse_move_total_rel_distance  \
# 0             1  ...                15.50704                       16.78128
# 1             1  ...                15.50704                       16.78128
# 2             2  ...                15.76245                       16.67535
# 3             2  ...                15.76245                       16.67535
# 4             2  ...                15.76245                       16.67535
#
#    browser_name  pct_rage_click  session_duration  pct_mouse_click  job  sex  \
# 0             1        73.88232          93.50794              NaN    1    1
# 1             1        73.88232          93.50794              NaN    2    1
# 2             2        36.27018          83.05534         15.63971    3    2
# 3             2        36.27018          83.05534         15.63971    4    2
# 4             2        36.27018          83.05534         15.63971    5    1
#
#    race  age
# 0     1   35
# 1     1   59
# 2     1    7
# 3     1   72
# 4     2   85
#
# [5 rows x 28 columns]

# %% [markdown]
# Následne objectové atribúty zmeníme na číselne pomocou Ordinal Encoding

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15109 entries, 0 to 15108
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  15097 non-null  float64
#  1   screen_height                   15109 non-null  int32
#  2   pct_input                       15097 non-null  float64
#  3   pct_scrandom                    15095 non-null  float64
#  4   pct_scroll_move                 15095 non-null  float64
#  5   pct_click_product_info          15095 non-null  float64
#  6   wild_mouse_duration             15091 non-null  float64
#  7   total_load_time                 15109 non-null  float64
#  8   pct_click                       15094 non-null  float64
#  9   screen_width                    15109 non-null  int32
#  10  pct_doubleclick                 15092 non-null  float64
#  11  product_ean                     15109 non-null  int64
#  12  pct_mouse_move                  15096 non-null  float64
#  13  user_id                         15109 non-null  int64
#  14  session_id                      15109 non-null  int64
#  15  pct_scroll_move_duration        15097 non-null  float64
#  16  ack                             15109 non-null  int32
#  17  scroll_move_total_rel_distance  15097 non-null  float64
#  18  page_activity_duration          15093 non-null  float64
#  19  mouse_move_total_rel_distance   15091 non-null  float64
#  20  browser_name                    15109 non-null  int32
#  21  pct_rage_click                  15092 non-null  float64
#  22  session_duration                15109 non-null  float64
#  23  pct_mouse_click                 15093 non-null  float64
#  24  job                             15109 non-null  int32
#  25  sex                             15109 non-null  int32
#  26  race                            15109 non-null  int32
#  27  age                             15109 non-null  int32
# dtypes: float64(17), int32(8), int64(3)
# memory usage: 2.8 MB

# %%
means = merged_data.mean()
merged_data = merged_data.fillna(means)
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15109 entries, 0 to 15108
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  15109 non-null  float64
#  1   screen_height                   15109 non-null  int32
#  2   pct_input                       15109 non-null  float64
#  3   pct_scrandom                    15109 non-null  float64
#  4   pct_scroll_move                 15109 non-null  float64
#  5   pct_click_product_info          15109 non-null  float64
#  6   wild_mouse_duration             15109 non-null  float64
#  7   total_load_time                 15109 non-null  float64
#  8   pct_click                       15109 non-null  float64
#  9   screen_width                    15109 non-null  int32
#  10  pct_doubleclick                 15109 non-null  float64
#  11  product_ean                     15109 non-null  int64
#  12  pct_mouse_move                  15109 non-null  float64
#  13  user_id                         15109 non-null  int64
#  14  session_id                      15109 non-null  int64
#  15  pct_scroll_move_duration        15109 non-null  float64
#  16  ack                             15109 non-null  int32
#  17  scroll_move_total_rel_distance  15109 non-null  float64
#  18  page_activity_duration          15109 non-null  float64
#  19  mouse_move_total_rel_distance   15109 non-null  float64
#  20  browser_name                    15109 non-null  int32
#  21  pct_rage_click                  15109 non-null  float64
#  22  session_duration                15109 non-null  float64
#  23  pct_mouse_click                 15109 non-null  float64
#  24  job                             15109 non-null  int32
#  25  sex                             15109 non-null  int32
#  26  race                            15109 non-null  int32
#  27  age                             15109 non-null  int32
# dtypes: float64(17), int32(8), int64(3)
# memory usage: 2.8 MB

# %% [markdown]
# Dalej sme nahradili číselné hodnoty (tie, čo pred tým neboli object) priemerom

# %%
fig, ax = plt.subplots(figsize=(30, 20))
sns.boxplot(data=merged_data[['pct_wild_mouse', 'pct_input', 'pct_scrandom', 'pct_scroll_move', 'pct_click_product_info', 'wild_mouse_duration', 'total_load_time', 'pct_click']])
plt.show()
# Out:
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
fig, ax = plt.subplots(figsize=(30, 20))
sns.boxplot(data=merged_data[['pct_doubleclick', 'pct_mouse_move', 'pct_scroll_move_duration', 'scroll_move_total_rel_distance', 'page_activity_duration', 'mouse_move_total_rel_distance', 'pct_rage_click', 'pct_mouse_click']])
plt.show()
# Out:
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Na grafoch môžeme vidieť, že atribúty majú outlierov. Niektoré viac, niektoré menej. V grafe som obsiahla všetky atribúty, ktorých atribúty by bolo potrebné ošetriť na outlierov (ešte session duration, ale to som nedávala do grafu, lebo má veľké hodnoty oproti ostatným atribútom a nie je dobre vidieť potom ostatné)

# %%
#Funkcia prevzatá zo vzorových notebookov
def identify_outliers(a):
    lower = a.quantile(0.25) - 1.5 * stats.iqr(a)
    upper = a.quantile(0.75) + 1.5 * stats.iqr(a)
    
    return a[(a > upper) | (a < lower)]

# %%
def delete_outliers(merged_data):
    count=0
    pocet_zaznamov_na_zaciatku=merged_data.shape[0]
    for column in merged_data[['pct_doubleclick', 'pct_mouse_move', 'pct_scroll_move_duration', 'scroll_move_total_rel_distance', 'page_activity_duration', 'mouse_move_total_rel_distance', 'pct_rage_click', 'pct_mouse_click', 'pct_wild_mouse', 'pct_input', 'pct_scrandom', 'pct_scroll_move', 'pct_click_product_info', 'wild_mouse_duration', 'total_load_time', 'pct_click', 'session_duration']]:
        outliers = identify_outliers(merged_data[column])
        count+=outliers.count()
        merged_data=merged_data.drop(outliers.index)

    print(f'Počet vychýlených hodnôt je {count}')
    print(f'Percento zaznamov, ktore ostali v percentach: {merged_data.shape[0]*100/pocet_zaznamov_na_zaciatku}')
    return merged_data

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15109 entries, 0 to 15108
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  15109 non-null  float64
#  1   screen_height                   15109 non-null  int32
#  2   pct_input                       15109 non-null  float64
#  3   pct_scrandom                    15109 non-null  float64
#  4   pct_scroll_move                 15109 non-null  float64
#  5   pct_click_product_info          15109 non-null  float64
#  6   wild_mouse_duration             15109 non-null  float64
#  7   total_load_time                 15109 non-null  float64
#  8   pct_click                       15109 non-null  float64
#  9   screen_width                    15109 non-null  int32
#  10  pct_doubleclick                 15109 non-null  float64
#  11  product_ean                     15109 non-null  int64
#  12  pct_mouse_move                  15109 non-null  float64
#  13  user_id                         15109 non-null  int64
#  14  session_id                      15109 non-null  int64
#  15  pct_scroll_move_duration        15109 non-null  float64
#  16  ack                             15109 non-null  int32
#  17  scroll_move_total_rel_distance  15109 non-null  float64
#  18  page_activity_duration          15109 non-null  float64
#  19  mouse_move_total_rel_distance   15109 non-null  float64
#  20  browser_name                    15109 non-null  int32
#  21  pct_rage_click                  15109 non-null  float64
#  22  session_duration                15109 non-null  float64
#  23  pct_mouse_click                 15109 non-null  float64
#  24  job                             15109 non-null  int32
#  25  sex                             15109 non-null  int32
#  26  race                            15109 non-null  int32
#  27  age                             15109 non-null  int32
# dtypes: float64(17), int32(8), int64(3)
# memory usage: 2.8 MB

# %%
merged_data = delete_outliers(merged_data)
merged_data.info()
# Out:
# Počet vychýlených hodnôt je 2775
# Percento zaznamov, ktore ostali v percentach: 81.633463498577
# <class 'pandas.core.frame.DataFrame'>
# Index: 12334 entries, 0 to 15108
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   pct_wild_mouse                  12334 non-null  float64
#  1   screen_height                   12334 non-null  int32
#  2   pct_input                       12334 non-null  float64
#  3   pct_scrandom                    12334 non-null  float64
#  4   pct_scroll_move                 12334 non-null  float64
#  5   pct_click_product_info          12334 non-null  float64
#  6   wild_mouse_duration             12334 non-null  float64
#  7   total_load_time                 12334 non-null  float64
#  8   pct_click                       12334 non-null  float64
#  9   screen_width                    12334 non-null  int32
#  10  pct_doubleclick                 12334 non-null  float64
#  11  product_ean                     12334 non-null  int64
#  12  pct_mouse_move                  12334 non-null  float64
#  13  user_id                         12334 non-null  int64
#  14  session_id                      12334 non-null  int64
#  15  pct_scroll_move_duration        12334 non-null  float64
#  16  ack                             12334 non-null  int32
#  17  scroll_move_total_rel_distance  12334 non-null  float64
#  18  page_activity_duration          12334 non-null  float64
#  19  mouse_move_total_rel_distance   12334 non-null  float64
#  20  browser_name                    12334 non-null  int32
#  21  pct_rage_click                  12334 non-null  float64
#  22  session_duration                12334 non-null  float64
#  23  pct_mouse_click                 12334 non-null  float64
#  24  job                             12334 non-null  int32
#  25  sex                             12334 non-null  int32
#  26  race                            12334 non-null  int32
#  27  age                             12334 non-null  int32
# dtypes: float64(17), int32(8), int64(3)
# memory usage: 2.4 MB

# %% [markdown]
# Vymazanie outlierov, zistili sme, že skoro 20% dát sme stratili

# %%
def delete_outliers_quantile(merged_data):
    count=0
    for column in merged_data[['pct_doubleclick', 'pct_mouse_move', 'pct_scroll_move_duration', 'scroll_move_total_rel_distance', 'page_activity_duration', 'mouse_move_total_rel_distance', 'pct_rage_click', 'pct_mouse_click', 'pct_wild_mouse', 'pct_input', 'pct_scrandom', 'pct_scroll_move', 'pct_click_product_info', 'wild_mouse_duration', 'total_load_time', 'pct_click', 'session_duration']]:
        outliers = identify_outliers(merged_data[column])
        lower_q = merged_data[column].quantile(0.05)
        uper_q = merged_data[column].quantile(0.95)
        count+=outliers.count()
        merged_data[column] = merged_data[column].clip(lower_q, uper_q)
        
    print(f'Počet zmenenych hodnôt je {count}')
    return merged_data

# %%
#merged_data = delete_outliers_quantile(merged_data)
#merged_data.info()

# %% [markdown]
# Alternatíva pre outlierov je, že ich nahradím hraničnými hodnotami, teda quantilom 0.05 alebo 0.95
